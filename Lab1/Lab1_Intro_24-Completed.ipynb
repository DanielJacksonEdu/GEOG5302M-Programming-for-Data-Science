# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielJacksonEdu/GEOG5302M-Programming-for-Data-Science/blob/main/Lab1/Lab1_Intro_24-Completed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1
# ## Introduction to Data Science

# %% [markdown]
# Welcome to the first lab for GEOG5302 Data Science for Practical Applciations! Although you'll be using Python and Jupyter in your Programming for Data Science module, and some of you may have experience of various aspects of programming, today's session is designed for you to familiarise yourself with Jupyter Notebooks and get some practice!

# %% [markdown]
# A Jupyter Notebook is _"an open source web application that you can use to create and share documents that contain live code, equations, visualizations, and text."_ [More Info](https://realpython.com/jupyter-notebook-introduction/)

# %% [markdown]
# Jupyter Notebooks are made up of a series of _cells_ (the boxes) which can be filled with code, images, or text (in Markdown format. [More info on formatting your Markdown](https://www.markdownguide.org/basic-syntax/))<br>
# If you hover over a cell, an arrow will appear on the left, for you to _run_ to code. Click on the cell and your cursor will appear, for you to edit or add code.

# %% [markdown]
# In this lab, you'll work through a Jupyter Notebook, running sections of code to learn new analysis skills. There will be some places to edit and write your own code, to practice what you've learnt. Helpers are around if you get stuck or if anything isn't clear. There are no silly questions- please just ask!

# %% [markdown]
# <br> <br> <br>
# ## Running a Cell

# %% [markdown]
# To run a cell, first select it, then either: <br>
# 1. Click the arrow that appears to the left of the cell <br>
# OR <br>
# 2. Use your keyboard. CTRL+ENTER (or COMMAND+ENTER on a Mac)runs and stays in the same cell. SHIFT+ENTER runs and moves to the next cell

# %% [markdown]
# A code cell that has yet to be run will have empty square brackets on the left: `[]` <br>
# When a cell has been run, a number will appear in the square brackets. The numbers refer to the order in which the cells have been run. E.g. `[1]` or `[5]`

# %% [markdown]
# <br> <br> <br>
# ## Editing a Cell

# %% [markdown]
# To add a cell, select it, then type 'a' to insert a cell above, 'b' to insert a cell below. <br>
# The added cell will by default be for code. If you want to switch to Markdown (to add a block of text), tap the 'm' key. <br>
# You can also use the 'Insert' button in the menu at the top of the page, or hover between cells to see a pop-up, choosing whether you want to add code or text <br>
# To delete a cell, click the little bin in the pop-up menu that appears at the top right of the selected cell <br>
# This pop-up menu also allows you to reorder your cells, using the up and down arrows

# %% [markdown]
# You can also add text comments within your blocks of code, which are really useful for explaining what you've done, or why you've chosen a certain command/paramter. This is great for making your code more readable by yourself and other people. Use a hastag `#` to tell Python this is a comment and shouldn't be run.
#
#    ` print('I wrote some code!') #the print command uses brackets and quotes`

# %% [markdown]
# <br> <br> <br>
# ## What's a Kernel?

# %% [markdown]
# You might also have noticed a menu item at the top of the screen called __Runtime__ (in some formats of Jupyter, this is called a  __Kernel__).
# A Runtime or Kernel basically keeps track of which code has been run, and which outputs have been produced, within this session. The main way we will be using this is, if you want to clear all your outputs (the pieces of information that Python produces after you run a cell) so you can start from scratch, you can click 'Restart & Clear Output'. If you want to check that your entire code notebook runs through without any issues, you might want to 'Restart & Run All'. Alternatively, if something has gone wrong and Python gets stuck trying to run something, you can 'Interrupt', edit your code, and try again. None of these actions will affect the code you have written, only whether the actions within the code have been completed this time around.

# %% [markdown]
# <br> <br> <br>
# ## Getting started with some coding

# %% [markdown]
# Now we know the basics of using a Jupyter Notebook, it's time to get coding!

# %% [markdown]
# In coding tradition, the first thing we are going to print is `Hello World!`. Run the cell below to see what happens.

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# The `print()` command prints to your screen. The quotation marks let Python know the data is in a text (technically known as a 'string') format. We can use double or single quotations eg `"Hello World!"` or `'Hello World'`, as long as we're consistent each time. <br>
# Try printing different text in the cell below. What happens if you use mis-matched quotations, or leave them out? You may notice that the cell has a red light when something has gone wrong!

# %%
#print with double " " quotations
print("Hello World")
# Out:
# Hello World

# %%
#print with mismatched quotations
#print('Hello World")

# %%
#print without quotations
#print(hello)

# %% [markdown]
# We'll now try some basic maths to see how this works in Python

# %%
3+4
# Out:
# 7

# %% [markdown]
# If we print 3+4 we get the same output

# %%
print(3+4)
# Out:
# 7

# %% [markdown]
# however, if we print '3+4', Python reads this in as text and not numbers

# %%
#print with quotations
print('3+4')
# Out:
# 3+4

# %% [markdown]
# If we want to be able to come back to our answer without having to recalculate it every time, we can assign it to a variable

# %%
answer = 3+4

# %% [markdown]
# We can print the variable

# %%
print(answer)
# Out:
# 7

# %% [markdown]
# See how this is different when calling `print()` on the variable, compared to if we use quotes- try it out below

# %%
#print with quotations
print('answer')
# Out:
# answer

# %% [markdown]
# Or we can just call the variable by name

# %%
answer
# Out:
# 7

# %% [markdown]
# And as our variable is a number, we can use it in another calculation

# %%
answer * 2
# Out:
# 14

# %% [markdown]
# <br> <br> <br>
# ## Importing Packages

# %% [markdown]
# Python has a lot of basic commands built in, but to extend the functionality, we can load in packages (also known as modules). These are extra libraries of code, written by other people, which allow us to do more specific analyses. Python Programmers tend to load in all their packages in one go at the beginning of their code.
# <br><br>
# The command for installing packages is `import package_name`
# <br><br>
# We'll start by importing the [pandas package](https://pandas.pydata.org/docs/user_guide/index.html), which is designed for real-world data analysis, so we'll be using it a lot in these labs! It allows easy handling of data frames such as .csv files, a bit like Excel.
# <br>
# When we use the functions provided by a specialist package, we have to tell Python where to look for the commands, for example, `pandas.read_csv('file-name')`.
# <br><br>
# As we'll be using these such a lot, we can use a common abbrevation to save time, and then the command is shortened to `pd.read_csv('file-name')`

# %%
import pandas as pd #importing pandas and giving it the nickname pd

# %% [markdown]
# <br> <br> <br>
# ## Reading in Data

# %% [markdown]
# We're now ready to get started with some data analytics (which is what we're all here for!). First we load in our dataset. This week, we're going to be working with a London Borough dataset `London_Boroughs.csv`, which includes various demographic and environmental profile data for each Borough in London. It's easiest if you save the file in the same folder as you've saved this Notebook. We've also provided a data dictionary in the same folder on Minerva, which provides more information on each of the variables. To be able to open the data in Colab, you'll need to upload the files, using the file-shaped icon on the left, and then the up arrow.

# %%
boroughs = pd.read_csv('London_Boroughs.csv') #remember to include the file extension!

# %% [markdown]
# To view the data frame, we can call it up by its name `boroughs`.

# %%
boroughs
# Out:
#          Code               Area_name Inner_Outer_London  Population    Area  \
# 0   E09000001          City of London       Inner London        8800    2.90
# 1   E09000002    Barking and Dagenham       Outer London      209000   36.11
# 2   E09000003                  Barnet       Outer London      389600   86.75
# 3   E09000004                  Bexley       Outer London      244300   60.58
# 4   E09000005                   Brent       Outer London      332100   43.23
# 5   E09000006                 Bromley       Outer London      327900  150.13
# 6   E09000007                  Camden       Inner London      242500   21.79
# 7   E09000008                 Croydon       Outer London      386500   86.50
# 8   E09000009                  Ealing       Outer London      351600   55.54
# 9   E09000010                 Enfield       Outer London      333000   80.83
# 10  E09000011               Greenwich       Outer London      280100   47.33
# 11  E09000012                 Hackney       Inner London      274300   19.05
# 12  E09000013  Hammersmith and Fulham       Inner London      185300   16.40
# 13  E09000014                Haringey       Inner London      278000   29.60
# 14  E09000015                  Harrow       Outer London      252300   50.46
# 15  E09000016                Havering       Outer London      254300  112.35
# 16  E09000017              Hillingdon       Outer London      301000  115.70
# 17  E09000018                Hounslow       Outer London      274200   55.98
# 18  E09000019               Islington       Inner London      231200   14.86
# 19  E09000020  Kensington and Chelsea       Inner London      159000   12.12
# 20  E09000021    Kingston upon Thames       Outer London      175400   37.26
# 21  E09000022                 Lambeth       Inner London      328900   26.81
# 22  E09000023                Lewisham       Inner London      303400   35.15
# 23  E09000024                  Merton       Outer London      208100   37.62
# 24  E09000025                  Newham       Inner London      342900   36.20
# 25  E09000026               Redbridge       Outer London      304200   56.42
# 26  E09000027    Richmond upon Thames       Outer London      197300   57.41
# 27  E09000028               Southwark       Inner London      314300   28.86
# 28  E09000029                  Sutton       Outer London      202600   43.85
# 29  E09000030           Tower Hamlets       Inner London      304000   19.78
# 30  E09000031          Waltham Forest       Outer London      276200   38.81
# 31  E09000032              Wandsworth       Inner London      321000   34.26
# 32  E09000033             Westminster       Inner London      242100   21.49
#
#     Average_Age Largest_migrant_population  Employment_rate Median_income  \
# 0          43.2              United States             64.6        63,620
# 1          32.9                    Nigeria             65.8        29,420
# 2          37.3                      India             68.5        40,530
# 3          39.0                    Nigeria             75.1        36,990
# 4          35.6                      India             69.5        32,140
# 5          40.2                      India             75.3        43,060
# 6          36.4              United States             69.2        43,750
# 7          37.0                      India             75.4        37,000
# 8          36.2                      India             72.7        36,070
# 9          36.3                     Turkey             73.0        33,110
# 10         35.0                    Nigeria             72.1        35,350
# 11         33.1                     Turkey             69.0        35,140
# 12         35.7                     France             77.5        43,820
# 13         35.1                     Poland             71.3        35,420
# 14         38.3                      India             73.9        38,880
# 15         40.3                    Ireland             76.5        36,670
# 16         36.4                      India             73.2        37,040
# 17         35.8                      India             74.2        35,330
# 18         34.8                    Ireland             72.6        39,790
# 19         39.3              United States             68.2        55,620
# 20         37.1                  Sri Lanka             74.4        43,940
# 21         34.5                    Jamaica             78.5        38,490
# 22         35.0                    Jamaica             75.9        35,900
# 23         36.7                     Poland             78.8        41,960
# 24         32.1                      India             66.2        28,780
# 25         35.8                      India             68.3        36,860
# 26         38.8                    Ireland             79.6        53,470
# 27         34.4                    Nigeria             74.2        37,100
# 28         38.9                  Sri Lanka             78.2        39,940
# 29         31.4                 Bangladesh             70.4        34,930
# 30         35.1                   Pakistan             73.1        33,080
# 31         35.0                     Poland             78.8        47,480
# 32         37.7              United States             65.6        47,510
#
#     Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 0           84.3  ...            NaN         4.8              1036
# 1            0.5  ...           20.3        33.6               644
# 2            0.7  ...           31.1        41.3              1415
# 3            0.6  ...           11.4        31.7               975
# 4            0.6  ...           34.8        21.9              1175
# 5            0.6  ...           14.1        57.8              1180
# 6            2.2  ...           32.0        24.8              1288
# 7            0.6  ...           18.6        37.1              1237
# 8            0.7  ...           35.0        30.9              1342
# 9            0.6  ...           21.0        45.6              1245
# 10           0.5  ...           19.7        34.4              1014
# 11           0.7  ...           23.3        23.2               813
# 12           1.2  ...           33.1        19.1               809
# 13           0.5  ...           23.9        25.5               773
# 14           0.6  ...           24.6        34.6               748
# 15           0.6  ...           13.8        59.3              1032
# 16           1.0  ...           28.2        49.2              1713
# 17           1.0  ...           28.3        39.6              1277
# 18           1.5  ...           25.5        12.4               878
# 19           1.4  ...           33.1        15.1              1154
# 20           0.8  ...           22.4        36.4               678
# 21           0.8  ...           34.4        17.3              1091
# 22           0.4  ...           23.6        22.5               825
# 23           0.7  ...           29.3        34.6               691
# 24           0.5  ...           42.5        23.9              1261
# 25           0.5  ...           24.1        40.6               874
# 26           0.8  ...           21.9        50.8               790
# 27           1.3  ...           26.4        24.9              1169
# 28           0.6  ...           20.5        32.0               666
# 29           1.4  ...           31.5        15.2              1703
# 30           0.5  ...           30.0        31.4               780
# 31           0.6  ...           31.2        26.9              1038
# 32           4.3  ...           43.3        38.2              2502
#
#     Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 0                  34.4          0.4               7.9                   NaN
# 1                  23.4          0.8               3.0                  77.6
# 2                  38.0          1.1               3.0                  82.1
# 3                  54.0          1.2               2.6                  80.4
# 4                  35.2          0.8               3.7                  80.1
# 5                  48.0          1.2               2.8                  81.4
# 6                  26.3          0.5               5.7                  81.8
# 7                  39.9          1.0               3.2                  80.3
# 8                  40.1          0.9               3.3                  80.6
# 9                  38.5          1.0               3.0                  80.7
# 10                 34.3          0.8               3.4                  79.0
# 11                 25.3          0.4               4.9                  78.5
# 12                 20.7          0.5               4.7                  79.7
# 13                 37.3          0.6               4.3                  80.1
# 14                 45.1          1.2               2.9                  82.7
# 15                 32.4          1.2               2.5                  80.2
# 16                 43.8          1.2               2.4                  80.4
# 17                 34.5          1.0               3.0                  80.0
# 18                 32.8          0.4               5.7                  79.0
# 19                 25.3          0.6               5.8                  83.3
# 20                 45.7          1.1               2.9                  82.0
# 21                 28.3          0.5               5.0                  78.9
# 22                 17.1          0.7               4.1                  79.0
# 23                 37.5          0.9               3.4                  80.4
# 24                 17.2          0.6               3.9                  78.5
# 25                 28.7          1.1               3.0                  80.9
# 26                 41.2          1.1               3.1                  82.4
# 27                 34.6          0.5               4.9                  78.9
# 28                 37.6          1.2               2.9                  80.9
# 29                 28.1          0.4               5.0                  78.1
# 30                 35.5          0.8               3.6                  79.4
# 31                 20.7          0.7               4.3                  79.5
# 32                 19.1          0.5               6.5                  82.3
#
#     Female_life_expectancy  Life_satisfaction              Council
# 0                      NaN                6.6                  NaN
# 1                     82.1                7.1                  Lab
# 2                     85.1                7.5                 Cons
# 3                     84.4                7.4                 Cons
# 4                     85.1                7.3                  Lab
# 5                     84.9                7.5                 Cons
# 6                     86.7                7.1                  Lab
# 7                     83.6                7.1                  Lab
# 8                     84.2                7.3                  Lab
# 9                     84.1                7.3                  Lab
# 10                    82.5                7.2                  Lab
# 11                    83.3                7.0                  Lab
# 12                    84.1                7.4                  Lab
# 13                    84.9                7.2                  Lab
# 14                    86.1                7.3                  Lab
# 15                    83.9                7.4   No Overall Control
# 16                    83.9                7.4                 Cons
# 17                    83.9                7.3                  Lab
# 18                    83.5                7.2                  Lab
# 19                    86.4                7.6                 Cons
# 20                    84.6                7.3                 Cons
# 21                    83.3                7.1                  Lab
# 22                    83.4                7.2                  Lab
# 23                    84.2                7.3                  Lab
# 24                    83.0                7.1                  Lab
# 25                    84.6                7.3                  Lab
# 26                    86.0                7.5                 Cons
# 27                    83.9                7.5                  Lab
# 28                    83.4                7.5              Lib Dem
# 29                    82.5                7.2  Tower Hamlets First
# 30                    83.8                7.2                  Lab
# 31                    83.7                7.4                 Cons
# 32                    86.3                7.3                 Cons
#
# [33 rows x 27 columns]

# %% [markdown]
# As you can see, pandas puts the data neatly in a table, so it's easy to work with. You can also scroll across to see all the variables. For big data sets, it can be helpful to just view the top 5 rows, using the command `dataframe.head()`

# %%
boroughs.head()
# Out:
#         Code             Area_name Inner_Outer_London  Population   Area  \
# 0  E09000001        City of London       Inner London        8800   2.90
# 1  E09000002  Barking and Dagenham       Outer London      209000  36.11
# 2  E09000003                Barnet       Outer London      389600  86.75
# 3  E09000004                Bexley       Outer London      244300  60.58
# 4  E09000005                 Brent       Outer London      332100  43.23
#
#    Average_Age Largest_migrant_population  Employment_rate Median_income  \
# 0         43.2              United States             64.6        63,620
# 1         32.9                    Nigeria             65.8        29,420
# 2         37.3                      India             68.5        40,530
# 3         39.0                    Nigeria             75.1        36,990
# 4         35.6                      India             69.5        32,140
#
#    Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 0          84.3  ...            NaN         4.8              1036
# 1           0.5  ...           20.3        33.6               644
# 2           0.7  ...           31.1        41.3              1415
# 3           0.6  ...           11.4        31.7               975
# 4           0.6  ...           34.8        21.9              1175
#
#    Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 0                 34.4          0.4               7.9                   NaN
# 1                 23.4          0.8               3.0                  77.6
# 2                 38.0          1.1               3.0                  82.1
# 3                 54.0          1.2               2.6                  80.4
# 4                 35.2          0.8               3.7                  80.1
#
#    Female_life_expectancy  Life_satisfaction  Council
# 0                     NaN                6.6      NaN
# 1                    82.1                7.1      Lab
# 2                    85.1                7.5     Cons
# 3                    84.4                7.4     Cons
# 4                    85.1                7.3      Lab
#
# [5 rows x 27 columns]

# %% [markdown]
# __IMPORTANT NOTE:__ Notice that Python starts counting from zero! So although `.head()` presents the top 5, the indices (numbers along the left) go from 0-4. While this isn't a problem, it's an important quirk to be aware of.
#
# <br>
# Five is the default number for this command. If we want to view a different number of rows, we can specify this in the brackets. This is what those empty brackets are doing, waiting for further instructions on the parameters they should use. If the brackets are empty, they revert to the standard, and many functions don't need any additional information.
# <br>
# Try loading the first 10 rows, then only the top one. Remember, it's a number, so doesn't need quotations.

# %%
#view first 10 rows
boroughs.head(10)
# Out:
#         Code             Area_name Inner_Outer_London  Population    Area  \
# 0  E09000001        City of London       Inner London        8800    2.90
# 1  E09000002  Barking and Dagenham       Outer London      209000   36.11
# 2  E09000003                Barnet       Outer London      389600   86.75
# 3  E09000004                Bexley       Outer London      244300   60.58
# 4  E09000005                 Brent       Outer London      332100   43.23
# 5  E09000006               Bromley       Outer London      327900  150.13
# 6  E09000007                Camden       Inner London      242500   21.79
# 7  E09000008               Croydon       Outer London      386500   86.50
# 8  E09000009                Ealing       Outer London      351600   55.54
# 9  E09000010               Enfield       Outer London      333000   80.83
#
#    Average_Age Largest_migrant_population  Employment_rate Median_income  \
# 0         43.2              United States             64.6        63,620
# 1         32.9                    Nigeria             65.8        29,420
# 2         37.3                      India             68.5        40,530
# 3         39.0                    Nigeria             75.1        36,990
# 4         35.6                      India             69.5        32,140
# 5         40.2                      India             75.3        43,060
# 6         36.4              United States             69.2        43,750
# 7         37.0                      India             75.4        37,000
# 8         36.2                      India             72.7        36,070
# 9         36.3                     Turkey             73.0        33,110
#
#    Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 0          84.3  ...            NaN         4.8              1036
# 1           0.5  ...           20.3        33.6               644
# 2           0.7  ...           31.1        41.3              1415
# 3           0.6  ...           11.4        31.7               975
# 4           0.6  ...           34.8        21.9              1175
# 5           0.6  ...           14.1        57.8              1180
# 6           2.2  ...           32.0        24.8              1288
# 7           0.6  ...           18.6        37.1              1237
# 8           0.7  ...           35.0        30.9              1342
# 9           0.6  ...           21.0        45.6              1245
#
#    Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 0                 34.4          0.4               7.9                   NaN
# 1                 23.4          0.8               3.0                  77.6
# 2                 38.0          1.1               3.0                  82.1
# 3                 54.0          1.2               2.6                  80.4
# 4                 35.2          0.8               3.7                  80.1
# 5                 48.0          1.2               2.8                  81.4
# 6                 26.3          0.5               5.7                  81.8
# 7                 39.9          1.0               3.2                  80.3
# 8                 40.1          0.9               3.3                  80.6
# 9                 38.5          1.0               3.0                  80.7
#
#    Female_life_expectancy  Life_satisfaction  Council
# 0                     NaN                6.6      NaN
# 1                    82.1                7.1      Lab
# 2                    85.1                7.5     Cons
# 3                    84.4                7.4     Cons
# 4                    85.1                7.3      Lab
# 5                    84.9                7.5     Cons
# 6                    86.7                7.1      Lab
# 7                    83.6                7.1      Lab
# 8                    84.2                7.3      Lab
# 9                    84.1                7.3      Lab
#
# [10 rows x 27 columns]

# %%
#view only top row
boroughs.head(1)
# Out:
#         Code       Area_name Inner_Outer_London  Population  Area  \
# 0  E09000001  City of London       Inner London        8800   2.9
#
#    Average_Age Largest_migrant_population  Employment_rate Median_income  \
# 0         43.2              United States             64.6        63,620
#
#    Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 0          84.3  ...            NaN         4.8              1036
#
#    Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 0                 34.4          0.4               7.9                   NaN
#
#    Female_life_expectancy  Life_satisfaction  Council
# 0                     NaN                6.6      NaN
#
# [1 rows x 27 columns]

# %% [markdown]
# Or we can see the last 5, using `dataframe.tail()`. Try it out below.

# %%
#view the tail of the data
boroughs.tail()
# Out:
#          Code       Area_name Inner_Outer_London  Population   Area  \
# 28  E09000029          Sutton       Outer London      202600  43.85
# 29  E09000030   Tower Hamlets       Inner London      304000  19.78
# 30  E09000031  Waltham Forest       Outer London      276200  38.81
# 31  E09000032      Wandsworth       Inner London      321000  34.26
# 32  E09000033     Westminster       Inner London      242100  21.49
#
#     Average_Age Largest_migrant_population  Employment_rate Median_income  \
# 28         38.9                  Sri Lanka             78.2        39,940
# 29         31.4                 Bangladesh             70.4        34,930
# 30         35.1                   Pakistan             73.1        33,080
# 31         35.0                     Poland             78.8        47,480
# 32         37.7              United States             65.6        47,510
#
#     Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 28           0.6  ...           20.5        32.0               666
# 29           1.4  ...           31.5        15.2              1703
# 30           0.5  ...           30.0        31.4               780
# 31           0.6  ...           31.2        26.9              1038
# 32           4.3  ...           43.3        38.2              2502
#
#     Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 28                 37.6          1.2               2.9                  80.9
# 29                 28.1          0.4               5.0                  78.1
# 30                 35.5          0.8               3.6                  79.4
# 31                 20.7          0.7               4.3                  79.5
# 32                 19.1          0.5               6.5                  82.3
#
#     Female_life_expectancy  Life_satisfaction              Council
# 28                    83.4                7.5              Lib Dem
# 29                    82.5                7.2  Tower Hamlets First
# 30                    83.8                7.2                  Lab
# 31                    83.7                7.4                 Cons
# 32                    86.3                7.3                 Cons
#
# [5 rows x 27 columns]

# %% [markdown]
# <br> <br> <br>
# ## Working with Dataframes

# %% [markdown]
# To find out a bit more about the data and variables, we can use the `dataframe.info()` function. This lists all the columns, how many instances there are, and what type (dtype) each is.

# %%
boroughs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Code                        33 non-null     object
#  1   Area_name                   33 non-null     object
#  2   Inner_Outer_London          33 non-null     object
#  3   Population                  33 non-null     int64
#  4   Area                        33 non-null     float64
#  5   Average_Age                 33 non-null     float64
#  6   Largest_migrant_population  33 non-null     object
#  7   Employment_rate             33 non-null     float64
#  8   Median_income               33 non-null     object
#  9   Jobs_Density                33 non-null     float64
#  10  Number_businesses           33 non-null     object
#  11  Crime_rate                  32 non-null     float64
#  12  Ambulance_incidents         32 non-null     float64
#  13  Median_House_Price          33 non-null     int64
#  14  New_Homes                   33 non-null     int64
#  15  Homes_Owned                 32 non-null     float64
#  16  Rented_HA                   32 non-null     float64
#  17  Rented_private              32 non-null     float64
#  18  Greenspace                  33 non-null     float64
#  19  Carbon_emissions            33 non-null     int64
#  20  Household_recycling         33 non-null     float64
#  21  Cars_per_HH                 33 non-null     float64
#  22  Public_transport            33 non-null     float64
#  23  Male_life_expectancy        32 non-null     float64
#  24  Female_life_expectancy      32 non-null     float64
#  25  Life_satisfaction           33 non-null     float64
#  26  Council                     32 non-null     object
# dtypes: float64(16), int64(4), object(7)
# memory usage: 7.1+ KB

# %% [markdown]
# There are several different types of data in the London Boroughs data set: <br>
# __object:__ is a text/string, eg 'Hello World!' <br>
# __int64:__ is an integer (numeric character), eg 3 <br>
# __float64:__ is a float, a number with decimal places, eg 3.14159 <br><br>
# There are a couple more you'll encounter at various points: <br>
# __datetime:__ values giving a point in time, either using date, time or both, eg: 2024-10-03 10:23:07.2324 is the 3rd October 2024, just after 23 minutes and 7 seconds past 10. <br>
# __boolean:__ binary data, which is assigned either True or False

# %% [markdown]
# For numeric data, we can find out more using the `dataframe.describe()` function. This brings up descriptive statistics of all numeric (integer and float) variables. Note that this doesn't bring up any information on our object-type variables.

# %%
#try descibing the data
boroughs.describe()
# Out:
#           Population        Area  Average_Age  Employment_rate  Jobs_Density  \
# count      33.000000   33.000000    33.000000        33.000000     33.000000
# mean   267739.393939   47.640303    36.375758        72.715152      3.442424
# std     75383.345058   32.708569     2.487849         4.219384     14.533195
# min      8800.000000    2.900000    31.400000        64.600000      0.400000
# 25%    231200.000000   26.810000    35.000000        69.200000      0.600000
# 50%    276200.000000   37.620000    36.200000        73.100000      0.700000
# 75%    321000.000000   56.420000    37.700000        75.400000      1.000000
# max    389600.000000  150.130000    43.200000        79.600000     84.300000
#
#        Crime_rate  Ambulance_incidents  Median_House_Price    New_Homes  \
# count   32.000000            32.000000        3.300000e+01    33.000000
# mean    84.868750            12.293750        4.654680e+05   920.909091
# std     31.129329             1.867884        2.043563e+05   658.755283
# min     50.400000             9.700000        2.435000e+05  -130.000000
# 25%     63.800000            11.300000        3.450000e+05   480.000000
# 50%     77.500000            12.050000        4.100000e+05   830.000000
# 75%     99.675000            12.825000        4.850000e+05  1350.000000
# max    212.400000            19.900000        1.200000e+06  2740.000000
#
#        Homes_Owned  Rented_HA  Rented_private  Greenspace  Carbon_emissions  \
# count    32.000000  32.000000       32.000000   33.000000         33.000000
# mean     22.140625  23.037500       26.653125   31.412121       1085.333333
# std       8.372029  10.436189        7.584023   12.673120        377.386296
# min       7.000000   8.700000       11.400000    4.800000        644.000000
# 25%      16.950000  14.975000       21.675000   23.200000        809.000000
# 50%      21.150000  19.600000       25.950000   31.700000       1036.000000
# 75%      28.150000  31.900000       31.625000   38.200000       1245.000000
# max      38.100000  45.400000       43.300000   59.300000       2502.000000
#
#        Household_recycling  Cars_per_HH  Public_transport  \
# count            33.000000    33.000000         33.000000
# mean             33.351515     0.815152          3.951515
# std               9.194228     0.289527          1.304588
# min              17.100000     0.400000          2.400000
# 25%              26.300000     0.500000          3.000000
# 50%              34.500000     0.800000          3.400000
# 75%              38.500000     1.100000          4.900000
# max              54.000000     1.200000          7.900000
#
#        Male_life_expectancy  Female_life_expectancy  Life_satisfaction
# count             32.000000               32.000000          33.000000
# mean              80.284375               84.231250           7.275758
# std                1.429439                1.156312           0.190444
# min               77.600000               82.100000           6.600000
# 25%               79.000000               83.475000           7.200000
# 50%               80.250000               84.000000           7.300000
# 75%               81.025000               84.900000           7.400000
# max               83.300000               86.700000           7.600000

# %% [markdown]
# To look more closely at individual columns, we can call them up by name or index (position), using the format `dataframe['column']` or `dataframe.column`. In these labs, we'll stick to the former, as it allows us to have spaces or unusal characters in our column names. We can then apply any function to an individual column, just as we did with the dataframe.

# %%
boroughs['Population'].head()
# Out:
# 0      8800
# 1    209000
# 2    389600
# 3    244300
# 4    332100
# Name: Population, dtype: int64

# %% [markdown]
# Try calling some of the other functions we've used to far (`.tail() .describe()`) on some different columns. Remember to use the correct capitalisation on the column names, or Python won't recognise them!

# %%
#view the tail of the column
boroughs['Carbon_emissions'].tail()
# Out:
# 28     666
# 29    1703
# 30     780
# 31    1038
# 32    2502
# Name: Carbon_emissions, dtype: int64

# %%
#desribe the column
boroughs['Carbon_emissions'].describe()
# Out:
# count      33.000000
# mean     1085.333333
# std       377.386296
# min       644.000000
# 25%       809.000000
# 50%      1036.000000
# 75%      1245.000000
# max      2502.000000
# Name: Carbon_emissions, dtype: float64

# %% [markdown]
# We'll look more at statistics in future labs, but we can quickly and easily find out some basic stats for our numeric columns, using the functions brought up by describe. Let's start by getting the average Borough population.

# %%
boroughs['Population'].mean()
# Out:
# 267739.3939393939

# %% [markdown]
# Can you also find the median?

# %%
#find the median of the column
boroughs['Population'].median()
# Out:
# 276200.0

# %% [markdown]
# We can also look at the extreme values, such as the Borough with the highest population:

# %%
boroughs['Population'].max()
# Out:
# 389600

# %% [markdown]
# Can you find the lowest Borough population?

# %%
#find the minimum column value
boroughs['Population'].min()
# Out:
# 8800

# %% [markdown]
# We can also sort the data by one or more columns. The default is in ascending order:

# %%
boroughs.sort_values(by = 'Population')
# Out:
#          Code               Area_name Inner_Outer_London  Population    Area  \
# 0   E09000001          City of London       Inner London        8800    2.90
# 19  E09000020  Kensington and Chelsea       Inner London      159000   12.12
# 20  E09000021    Kingston upon Thames       Outer London      175400   37.26
# 12  E09000013  Hammersmith and Fulham       Inner London      185300   16.40
# 26  E09000027    Richmond upon Thames       Outer London      197300   57.41
# 28  E09000029                  Sutton       Outer London      202600   43.85
# 23  E09000024                  Merton       Outer London      208100   37.62
# 1   E09000002    Barking and Dagenham       Outer London      209000   36.11
# 18  E09000019               Islington       Inner London      231200   14.86
# 32  E09000033             Westminster       Inner London      242100   21.49
# 6   E09000007                  Camden       Inner London      242500   21.79
# 3   E09000004                  Bexley       Outer London      244300   60.58
# 14  E09000015                  Harrow       Outer London      252300   50.46
# 15  E09000016                Havering       Outer London      254300  112.35
# 17  E09000018                Hounslow       Outer London      274200   55.98
# 11  E09000012                 Hackney       Inner London      274300   19.05
# 30  E09000031          Waltham Forest       Outer London      276200   38.81
# 13  E09000014                Haringey       Inner London      278000   29.60
# 10  E09000011               Greenwich       Outer London      280100   47.33
# 16  E09000017              Hillingdon       Outer London      301000  115.70
# 22  E09000023                Lewisham       Inner London      303400   35.15
# 29  E09000030           Tower Hamlets       Inner London      304000   19.78
# 25  E09000026               Redbridge       Outer London      304200   56.42
# 27  E09000028               Southwark       Inner London      314300   28.86
# 31  E09000032              Wandsworth       Inner London      321000   34.26
# 5   E09000006                 Bromley       Outer London      327900  150.13
# 21  E09000022                 Lambeth       Inner London      328900   26.81
# 4   E09000005                   Brent       Outer London      332100   43.23
# 9   E09000010                 Enfield       Outer London      333000   80.83
# 24  E09000025                  Newham       Inner London      342900   36.20
# 8   E09000009                  Ealing       Outer London      351600   55.54
# 7   E09000008                 Croydon       Outer London      386500   86.50
# 2   E09000003                  Barnet       Outer London      389600   86.75
#
#     Average_Age Largest_migrant_population  Employment_rate Median_income  \
# 0          43.2              United States             64.6        63,620
# 19         39.3              United States             68.2        55,620
# 20         37.1                  Sri Lanka             74.4        43,940
# 12         35.7                     France             77.5        43,820
# 26         38.8                    Ireland             79.6        53,470
# 28         38.9                  Sri Lanka             78.2        39,940
# 23         36.7                     Poland             78.8        41,960
# 1          32.9                    Nigeria             65.8        29,420
# 18         34.8                    Ireland             72.6        39,790
# 32         37.7              United States             65.6        47,510
# 6          36.4              United States             69.2        43,750
# 3          39.0                    Nigeria             75.1        36,990
# 14         38.3                      India             73.9        38,880
# 15         40.3                    Ireland             76.5        36,670
# 17         35.8                      India             74.2        35,330
# 11         33.1                     Turkey             69.0        35,140
# 30         35.1                   Pakistan             73.1        33,080
# 13         35.1                     Poland             71.3        35,420
# 10         35.0                    Nigeria             72.1        35,350
# 16         36.4                      India             73.2        37,040
# 22         35.0                    Jamaica             75.9        35,900
# 29         31.4                 Bangladesh             70.4        34,930
# 25         35.8                      India             68.3        36,860
# 27         34.4                    Nigeria             74.2        37,100
# 31         35.0                     Poland             78.8        47,480
# 5          40.2                      India             75.3        43,060
# 21         34.5                    Jamaica             78.5        38,490
# 4          35.6                      India             69.5        32,140
# 9          36.3                     Turkey             73.0        33,110
# 24         32.1                      India             66.2        28,780
# 8          36.2                      India             72.7        36,070
# 7          37.0                      India             75.4        37,000
# 2          37.3                      India             68.5        40,530
#
#     Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 0           84.3  ...            NaN         4.8              1036
# 19           1.4  ...           33.1        15.1              1154
# 20           0.8  ...           22.4        36.4               678
# 12           1.2  ...           33.1        19.1               809
# 26           0.8  ...           21.9        50.8               790
# 28           0.6  ...           20.5        32.0               666
# 23           0.7  ...           29.3        34.6               691
# 1            0.5  ...           20.3        33.6               644
# 18           1.5  ...           25.5        12.4               878
# 32           4.3  ...           43.3        38.2              2502
# 6            2.2  ...           32.0        24.8              1288
# 3            0.6  ...           11.4        31.7               975
# 14           0.6  ...           24.6        34.6               748
# 15           0.6  ...           13.8        59.3              1032
# 17           1.0  ...           28.3        39.6              1277
# 11           0.7  ...           23.3        23.2               813
# 30           0.5  ...           30.0        31.4               780
# 13           0.5  ...           23.9        25.5               773
# 10           0.5  ...           19.7        34.4              1014
# 16           1.0  ...           28.2        49.2              1713
# 22           0.4  ...           23.6        22.5               825
# 29           1.4  ...           31.5        15.2              1703
# 25           0.5  ...           24.1        40.6               874
# 27           1.3  ...           26.4        24.9              1169
# 31           0.6  ...           31.2        26.9              1038
# 5            0.6  ...           14.1        57.8              1180
# 21           0.8  ...           34.4        17.3              1091
# 4            0.6  ...           34.8        21.9              1175
# 9            0.6  ...           21.0        45.6              1245
# 24           0.5  ...           42.5        23.9              1261
# 8            0.7  ...           35.0        30.9              1342
# 7            0.6  ...           18.6        37.1              1237
# 2            0.7  ...           31.1        41.3              1415
#
#     Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 0                  34.4          0.4               7.9                   NaN
# 19                 25.3          0.6               5.8                  83.3
# 20                 45.7          1.1               2.9                  82.0
# 12                 20.7          0.5               4.7                  79.7
# 26                 41.2          1.1               3.1                  82.4
# 28                 37.6          1.2               2.9                  80.9
# 23                 37.5          0.9               3.4                  80.4
# 1                  23.4          0.8               3.0                  77.6
# 18                 32.8          0.4               5.7                  79.0
# 32                 19.1          0.5               6.5                  82.3
# 6                  26.3          0.5               5.7                  81.8
# 3                  54.0          1.2               2.6                  80.4
# 14                 45.1          1.2               2.9                  82.7
# 15                 32.4          1.2               2.5                  80.2
# 17                 34.5          1.0               3.0                  80.0
# 11                 25.3          0.4               4.9                  78.5
# 30                 35.5          0.8               3.6                  79.4
# 13                 37.3          0.6               4.3                  80.1
# 10                 34.3          0.8               3.4                  79.0
# 16                 43.8          1.2               2.4                  80.4
# 22                 17.1          0.7               4.1                  79.0
# 29                 28.1          0.4               5.0                  78.1
# 25                 28.7          1.1               3.0                  80.9
# 27                 34.6          0.5               4.9                  78.9
# 31                 20.7          0.7               4.3                  79.5
# 5                  48.0          1.2               2.8                  81.4
# 21                 28.3          0.5               5.0                  78.9
# 4                  35.2          0.8               3.7                  80.1
# 9                  38.5          1.0               3.0                  80.7
# 24                 17.2          0.6               3.9                  78.5
# 8                  40.1          0.9               3.3                  80.6
# 7                  39.9          1.0               3.2                  80.3
# 2                  38.0          1.1               3.0                  82.1
#
#     Female_life_expectancy  Life_satisfaction              Council
# 0                      NaN                6.6                  NaN
# 19                    86.4                7.6                 Cons
# 20                    84.6                7.3                 Cons
# 12                    84.1                7.4                  Lab
# 26                    86.0                7.5                 Cons
# 28                    83.4                7.5              Lib Dem
# 23                    84.2                7.3                  Lab
# 1                     82.1                7.1                  Lab
# 18                    83.5                7.2                  Lab
# 32                    86.3                7.3                 Cons
# 6                     86.7                7.1                  Lab
# 3                     84.4                7.4                 Cons
# 14                    86.1                7.3                  Lab
# 15                    83.9                7.4   No Overall Control
# 17                    83.9                7.3                  Lab
# 11                    83.3                7.0                  Lab
# 30                    83.8                7.2                  Lab
# 13                    84.9                7.2                  Lab
# 10                    82.5                7.2                  Lab
# 16                    83.9                7.4                 Cons
# 22                    83.4                7.2                  Lab
# 29                    82.5                7.2  Tower Hamlets First
# 25                    84.6                7.3                  Lab
# 27                    83.9                7.5                  Lab
# 31                    83.7                7.4                 Cons
# 5                     84.9                7.5                 Cons
# 21                    83.3                7.1                  Lab
# 4                     85.1                7.3                  Lab
# 9                     84.1                7.3                  Lab
# 24                    83.0                7.1                  Lab
# 8                     84.2                7.3                  Lab
# 7                     83.6                7.1                  Lab
# 2                     85.1                7.5                 Cons
#
# [33 rows x 27 columns]

# %% [markdown]
# To sort in descending order, we need to set on of the default parameters (ascending) to False. Try it below

# %%
boroughs.sort_values(by = 'Population', ascending = False )
# Out:
#          Code               Area_name Inner_Outer_London  Population    Area  \
# 2   E09000003                  Barnet       Outer London      389600   86.75
# 7   E09000008                 Croydon       Outer London      386500   86.50
# 8   E09000009                  Ealing       Outer London      351600   55.54
# 24  E09000025                  Newham       Inner London      342900   36.20
# 9   E09000010                 Enfield       Outer London      333000   80.83
# 4   E09000005                   Brent       Outer London      332100   43.23
# 21  E09000022                 Lambeth       Inner London      328900   26.81
# 5   E09000006                 Bromley       Outer London      327900  150.13
# 31  E09000032              Wandsworth       Inner London      321000   34.26
# 27  E09000028               Southwark       Inner London      314300   28.86
# 25  E09000026               Redbridge       Outer London      304200   56.42
# 29  E09000030           Tower Hamlets       Inner London      304000   19.78
# 22  E09000023                Lewisham       Inner London      303400   35.15
# 16  E09000017              Hillingdon       Outer London      301000  115.70
# 10  E09000011               Greenwich       Outer London      280100   47.33
# 13  E09000014                Haringey       Inner London      278000   29.60
# 30  E09000031          Waltham Forest       Outer London      276200   38.81
# 11  E09000012                 Hackney       Inner London      274300   19.05
# 17  E09000018                Hounslow       Outer London      274200   55.98
# 15  E09000016                Havering       Outer London      254300  112.35
# 14  E09000015                  Harrow       Outer London      252300   50.46
# 3   E09000004                  Bexley       Outer London      244300   60.58
# 6   E09000007                  Camden       Inner London      242500   21.79
# 32  E09000033             Westminster       Inner London      242100   21.49
# 18  E09000019               Islington       Inner London      231200   14.86
# 1   E09000002    Barking and Dagenham       Outer London      209000   36.11
# 23  E09000024                  Merton       Outer London      208100   37.62
# 28  E09000029                  Sutton       Outer London      202600   43.85
# 26  E09000027    Richmond upon Thames       Outer London      197300   57.41
# 12  E09000013  Hammersmith and Fulham       Inner London      185300   16.40
# 20  E09000021    Kingston upon Thames       Outer London      175400   37.26
# 19  E09000020  Kensington and Chelsea       Inner London      159000   12.12
# 0   E09000001          City of London       Inner London        8800    2.90
#
#     Average_Age Largest_migrant_population  Employment_rate Median_income  \
# 2          37.3                      India             68.5        40,530
# 7          37.0                      India             75.4        37,000
# 8          36.2                      India             72.7        36,070
# 24         32.1                      India             66.2        28,780
# 9          36.3                     Turkey             73.0        33,110
# 4          35.6                      India             69.5        32,140
# 21         34.5                    Jamaica             78.5        38,490
# 5          40.2                      India             75.3        43,060
# 31         35.0                     Poland             78.8        47,480
# 27         34.4                    Nigeria             74.2        37,100
# 25         35.8                      India             68.3        36,860
# 29         31.4                 Bangladesh             70.4        34,930
# 22         35.0                    Jamaica             75.9        35,900
# 16         36.4                      India             73.2        37,040
# 10         35.0                    Nigeria             72.1        35,350
# 13         35.1                     Poland             71.3        35,420
# 30         35.1                   Pakistan             73.1        33,080
# 11         33.1                     Turkey             69.0        35,140
# 17         35.8                      India             74.2        35,330
# 15         40.3                    Ireland             76.5        36,670
# 14         38.3                      India             73.9        38,880
# 3          39.0                    Nigeria             75.1        36,990
# 6          36.4              United States             69.2        43,750
# 32         37.7              United States             65.6        47,510
# 18         34.8                    Ireland             72.6        39,790
# 1          32.9                    Nigeria             65.8        29,420
# 23         36.7                     Poland             78.8        41,960
# 28         38.9                  Sri Lanka             78.2        39,940
# 26         38.8                    Ireland             79.6        53,470
# 12         35.7                     France             77.5        43,820
# 20         37.1                  Sri Lanka             74.4        43,940
# 19         39.3              United States             68.2        55,620
# 0          43.2              United States             64.6        63,620
#
#     Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 2            0.7  ...           31.1        41.3              1415
# 7            0.6  ...           18.6        37.1              1237
# 8            0.7  ...           35.0        30.9              1342
# 24           0.5  ...           42.5        23.9              1261
# 9            0.6  ...           21.0        45.6              1245
# 4            0.6  ...           34.8        21.9              1175
# 21           0.8  ...           34.4        17.3              1091
# 5            0.6  ...           14.1        57.8              1180
# 31           0.6  ...           31.2        26.9              1038
# 27           1.3  ...           26.4        24.9              1169
# 25           0.5  ...           24.1        40.6               874
# 29           1.4  ...           31.5        15.2              1703
# 22           0.4  ...           23.6        22.5               825
# 16           1.0  ...           28.2        49.2              1713
# 10           0.5  ...           19.7        34.4              1014
# 13           0.5  ...           23.9        25.5               773
# 30           0.5  ...           30.0        31.4               780
# 11           0.7  ...           23.3        23.2               813
# 17           1.0  ...           28.3        39.6              1277
# 15           0.6  ...           13.8        59.3              1032
# 14           0.6  ...           24.6        34.6               748
# 3            0.6  ...           11.4        31.7               975
# 6            2.2  ...           32.0        24.8              1288
# 32           4.3  ...           43.3        38.2              2502
# 18           1.5  ...           25.5        12.4               878
# 1            0.5  ...           20.3        33.6               644
# 23           0.7  ...           29.3        34.6               691
# 28           0.6  ...           20.5        32.0               666
# 26           0.8  ...           21.9        50.8               790
# 12           1.2  ...           33.1        19.1               809
# 20           0.8  ...           22.4        36.4               678
# 19           1.4  ...           33.1        15.1              1154
# 0           84.3  ...            NaN         4.8              1036
#
#     Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 2                  38.0          1.1               3.0                  82.1
# 7                  39.9          1.0               3.2                  80.3
# 8                  40.1          0.9               3.3                  80.6
# 24                 17.2          0.6               3.9                  78.5
# 9                  38.5          1.0               3.0                  80.7
# 4                  35.2          0.8               3.7                  80.1
# 21                 28.3          0.5               5.0                  78.9
# 5                  48.0          1.2               2.8                  81.4
# 31                 20.7          0.7               4.3                  79.5
# 27                 34.6          0.5               4.9                  78.9
# 25                 28.7          1.1               3.0                  80.9
# 29                 28.1          0.4               5.0                  78.1
# 22                 17.1          0.7               4.1                  79.0
# 16                 43.8          1.2               2.4                  80.4
# 10                 34.3          0.8               3.4                  79.0
# 13                 37.3          0.6               4.3                  80.1
# 30                 35.5          0.8               3.6                  79.4
# 11                 25.3          0.4               4.9                  78.5
# 17                 34.5          1.0               3.0                  80.0
# 15                 32.4          1.2               2.5                  80.2
# 14                 45.1          1.2               2.9                  82.7
# 3                  54.0          1.2               2.6                  80.4
# 6                  26.3          0.5               5.7                  81.8
# 32                 19.1          0.5               6.5                  82.3
# 18                 32.8          0.4               5.7                  79.0
# 1                  23.4          0.8               3.0                  77.6
# 23                 37.5          0.9               3.4                  80.4
# 28                 37.6          1.2               2.9                  80.9
# 26                 41.2          1.1               3.1                  82.4
# 12                 20.7          0.5               4.7                  79.7
# 20                 45.7          1.1               2.9                  82.0
# 19                 25.3          0.6               5.8                  83.3
# 0                  34.4          0.4               7.9                   NaN
#
#     Female_life_expectancy  Life_satisfaction              Council
# 2                     85.1                7.5                 Cons
# 7                     83.6                7.1                  Lab
# 8                     84.2                7.3                  Lab
# 24                    83.0                7.1                  Lab
# 9                     84.1                7.3                  Lab
# 4                     85.1                7.3                  Lab
# 21                    83.3                7.1                  Lab
# 5                     84.9                7.5                 Cons
# 31                    83.7                7.4                 Cons
# 27                    83.9                7.5                  Lab
# 25                    84.6                7.3                  Lab
# 29                    82.5                7.2  Tower Hamlets First
# 22                    83.4                7.2                  Lab
# 16                    83.9                7.4                 Cons
# 10                    82.5                7.2                  Lab
# 13                    84.9                7.2                  Lab
# 30                    83.8                7.2                  Lab
# 11                    83.3                7.0                  Lab
# 17                    83.9                7.3                  Lab
# 15                    83.9                7.4   No Overall Control
# 14                    86.1                7.3                  Lab
# 3                     84.4                7.4                 Cons
# 6                     86.7                7.1                  Lab
# 32                    86.3                7.3                 Cons
# 18                    83.5                7.2                  Lab
# 1                     82.1                7.1                  Lab
# 23                    84.2                7.3                  Lab
# 28                    83.4                7.5              Lib Dem
# 26                    86.0                7.5                 Cons
# 12                    84.1                7.4                  Lab
# 20                    84.6                7.3                 Cons
# 19                    86.4                7.6                 Cons
# 0                      NaN                6.6                  NaN
#
# [33 rows x 27 columns]

# %% [markdown]
# <br>We've spent a lot of time working with just one column in the data set. If we want to be able to quickly call this column, or manipulate it without affecting the original data, we can save it as a separate variable.

# %%
Population = boroughs['Population']

# %%
#view the head of the new Populatiom dataframe
Population.head()
# Out:
# 0      8800
# 1    209000
# 2    389600
# 3    244300
# 4    332100
# Name: Population, dtype: int64

# %%
Population.sort_values()
# Out:
# 0       8800
# 19    159000
# 20    175400
# 12    185300
# 26    197300
# 28    202600
# 23    208100
# 1     209000
# 18    231200
# 32    242100
# 6     242500
# 3     244300
# 14    252300
# 15    254300
# 17    274200
# 11    274300
# 30    276200
# 13    278000
# 10    280100
# 16    301000
# 22    303400
# 29    304000
# 25    304200
# 27    314300
# 31    321000
# 5     327900
# 21    328900
# 4     332100
# 9     333000
# 24    342900
# 8     351600
# 7     386500
# 2     389600
# Name: Population, dtype: int64

# %% [markdown]
# We'll be looking a lot more at plotting over the coming weeks, but an easy way to visualise numerical data is just by calling .hist() on a variable to generate a simple histogram. Type this after calling the variable, below:

# %%
boroughs['Population'].hist()
# Out:
# <Axes: >

# %% [markdown]
# <br><br>
# For categorical ('object') variables, it would be useful to know how many rows correspond to each category, or 'value'. For example, we can check how many Boroughs fall into inner or outer London. To do this, we use the `.value_counts()` function. Try it out:

# %%
boroughs['Inner_Outer_London'].value_counts()
# Out:
# Inner_Outer_London
# Outer London    19
# Inner London    14
# Name: count, dtype: int64

# %% [markdown]
# Try this out on the other categorical variables (e.g. Largest_migrant_population and Council), in the cells below

# %%
#count valyes of a new column
boroughs['Largest_migrant_population'].value_counts()
# Out:
# Largest_migrant_population
# India            10
# United States     4
# Nigeria           4
# Poland            3
# Ireland           3
# Turkey            2
# Sri Lanka         2
# Jamaica           2
# France            1
# Bangladesh        1
# Pakistan          1
# Name: count, dtype: int64

# %%
#count valyes of a new column
boroughs['Council'].value_counts()
# Out:
# Council
# Lab                    20
# Cons                    9
# No Overall Control      1
# Lib Dem                 1
# Tower Hamlets First     1
# Name: count, dtype: int64

# %% [markdown]
# We can also create subsets of multiple columns, using double square brackets, which indicate a list (ie`[['','']]`).

# %%
sub = boroughs[['Area_name', 'Population']]
sub
# Out:
#                  Area_name  Population
# 0           City of London        8800
# 1     Barking and Dagenham      209000
# 2                   Barnet      389600
# 3                   Bexley      244300
# 4                    Brent      332100
# 5                  Bromley      327900
# 6                   Camden      242500
# 7                  Croydon      386500
# 8                   Ealing      351600
# 9                  Enfield      333000
# 10               Greenwich      280100
# 11                 Hackney      274300
# 12  Hammersmith and Fulham      185300
# 13                Haringey      278000
# 14                  Harrow      252300
# 15                Havering      254300
# 16              Hillingdon      301000
# 17                Hounslow      274200
# 18               Islington      231200
# 19  Kensington and Chelsea      159000
# 20    Kingston upon Thames      175400
# 21                 Lambeth      328900
# 22                Lewisham      303400
# 23                  Merton      208100
# 24                  Newham      342900
# 25               Redbridge      304200
# 26    Richmond upon Thames      197300
# 27               Southwark      314300
# 28                  Sutton      202600
# 29           Tower Hamlets      304000
# 30          Waltham Forest      276200
# 31              Wandsworth      321000
# 32             Westminster      242100

# %% [markdown]
# Try creating a subset with three and four columns below:

# %%
sub2 = boroughs[['Area_name', 'Population', 'Carbon_emissions']]
sub2
#create a subset with three columns
# Out:
#                  Area_name  Population  Carbon_emissions
# 0           City of London        8800              1036
# 1     Barking and Dagenham      209000               644
# 2                   Barnet      389600              1415
# 3                   Bexley      244300               975
# 4                    Brent      332100              1175
# 5                  Bromley      327900              1180
# 6                   Camden      242500              1288
# 7                  Croydon      386500              1237
# 8                   Ealing      351600              1342
# 9                  Enfield      333000              1245
# 10               Greenwich      280100              1014
# 11                 Hackney      274300               813
# 12  Hammersmith and Fulham      185300               809
# 13                Haringey      278000               773
# 14                  Harrow      252300               748
# 15                Havering      254300              1032
# 16              Hillingdon      301000              1713
# 17                Hounslow      274200              1277
# 18               Islington      231200               878
# 19  Kensington and Chelsea      159000              1154
# 20    Kingston upon Thames      175400               678
# 21                 Lambeth      328900              1091
# 22                Lewisham      303400               825
# 23                  Merton      208100               691
# 24                  Newham      342900              1261
# 25               Redbridge      304200               874
# 26    Richmond upon Thames      197300               790
# 27               Southwark      314300              1169
# 28                  Sutton      202600               666
# 29           Tower Hamlets      304000              1703
# 30          Waltham Forest      276200               780
# 31              Wandsworth      321000              1038
# 32             Westminster      242100              2502

# %%
sub3 = boroughs[['Area_name', 'Population', 'Carbon_emissions', 'Average_Age']]
sub3
#create a subset with four columns
# Out:
#                  Area_name  Population  Carbon_emissions  Average_Age
# 0           City of London        8800              1036         43.2
# 1     Barking and Dagenham      209000               644         32.9
# 2                   Barnet      389600              1415         37.3
# 3                   Bexley      244300               975         39.0
# 4                    Brent      332100              1175         35.6
# 5                  Bromley      327900              1180         40.2
# 6                   Camden      242500              1288         36.4
# 7                  Croydon      386500              1237         37.0
# 8                   Ealing      351600              1342         36.2
# 9                  Enfield      333000              1245         36.3
# 10               Greenwich      280100              1014         35.0
# 11                 Hackney      274300               813         33.1
# 12  Hammersmith and Fulham      185300               809         35.7
# 13                Haringey      278000               773         35.1
# 14                  Harrow      252300               748         38.3
# 15                Havering      254300              1032         40.3
# 16              Hillingdon      301000              1713         36.4
# 17                Hounslow      274200              1277         35.8
# 18               Islington      231200               878         34.8
# 19  Kensington and Chelsea      159000              1154         39.3
# 20    Kingston upon Thames      175400               678         37.1
# 21                 Lambeth      328900              1091         34.5
# 22                Lewisham      303400               825         35.0
# 23                  Merton      208100               691         36.7
# 24                  Newham      342900              1261         32.1
# 25               Redbridge      304200               874         35.8
# 26    Richmond upon Thames      197300               790         38.8
# 27               Southwark      314300              1169         34.4
# 28                  Sutton      202600               666         38.9
# 29           Tower Hamlets      304000              1703         31.4
# 30          Waltham Forest      276200               780         35.1
# 31              Wandsworth      321000              1038         35.0
# 32             Westminster      242100              2502         37.7

# %% [markdown]
# If we want to get rid of any columns (for example any duplicate information, or data we no longer need) we can use a simple `.drop()` function to remove them. Type the name of the duplicate column below to drop it from the dataset, then run `head()` to check it's worked.

# %%
sub4 = sub.drop(['Population'], axis = 1)
#the axis tells Python it's looking for a column name.
# 1 means column, 0 means row, and is the default (so if we don't specify which axis, Python will assume it's a row)

# %% [markdown]
# Now look at the top of the subset, to check it's worked:

# %%
#view the top of sub4
sub4.head()
# Out:
#               Area_name
# 0        City of London
# 1  Barking and Dagenham
# 2                Barnet
# 3                Bexley
# 4                 Brent

# %% [markdown]
# <br><br>
# We can also look at multiple groups at once- for example, which political party has the most seats in Inner and Outer London? This needs the `groupby()` function, which groups the data, and the `size()` function, which tells us the size of each group.

# %%
boroughs.groupby(['Inner_Outer_London', 'Council']).size()
# Out:
# Inner_Outer_London  Council
# Inner London        Cons                    3
#                     Lab                     9
#                     Tower Hamlets First     1
# Outer London        Cons                    6
#                     Lab                    11
#                     Lib Dem                 1
#                     No Overall Control      1
# dtype: int64

# %% [markdown]
# Can you call up the size of different migrant populations within inner and outer London?

# %%
#view the size
boroughs.groupby(['Inner_Outer_London', 'Largest_migrant_population']).size()
# Out:
# Inner_Outer_London  Largest_migrant_population
# Inner London        Bangladesh                    1
#                     France                        1
#                     India                         1
#                     Ireland                       1
#                     Jamaica                       2
#                     Nigeria                       1
#                     Poland                        2
#                     Turkey                        1
#                     United States                 4
# Outer London        India                         9
#                     Ireland                       2
#                     Nigeria                       3
#                     Pakistan                      1
#                     Poland                        1
#                     Sri Lanka                     2
#                     Turkey                        1
# dtype: int64

# %% [markdown]
# How about the different migrant populations by Council Party?

# %%
#view the size
boroughs.groupby(['Council', 'Largest_migrant_population']).size()
# Out:
# Council              Largest_migrant_population
# Cons                 India                         3
#                      Ireland                       1
#                      Nigeria                       1
#                      Poland                        1
#                      Sri Lanka                     1
#                      United States                 2
# Lab                  France                        1
#                      India                         7
#                      Ireland                       1
#                      Jamaica                       2
#                      Nigeria                       3
#                      Pakistan                      1
#                      Poland                        2
#                      Turkey                        2
#                      United States                 1
# Lib Dem              Sri Lanka                     1
# No Overall Control   Ireland                       1
# Tower Hamlets First  Bangladesh                    1
# dtype: int64

# %% [markdown]
# <br><br><br>
# ## Accessing rows and columns

# %% [markdown]
# It's pretty straightforward to select a column by name. We'll now look at how to select by index (the position of the column. Remember: Python starts counting from 0!) <br>
# We can access the column 'Inner_Outer_London', which tells us which part of London our Borough falls in, by name:

# %%
boroughs['Inner_Outer_London']
# Out:
# 0     Inner London
# 1     Outer London
# 2     Outer London
# 3     Outer London
# 4     Outer London
# 5     Outer London
# 6     Inner London
# 7     Outer London
# 8     Outer London
# 9     Outer London
# 10    Outer London
# 11    Inner London
# 12    Inner London
# 13    Inner London
# 14    Outer London
# 15    Outer London
# 16    Outer London
# 17    Outer London
# 18    Inner London
# 19    Inner London
# 20    Outer London
# 21    Inner London
# 22    Inner London
# 23    Outer London
# 24    Inner London
# 25    Outer London
# 26    Outer London
# 27    Inner London
# 28    Outer London
# 29    Inner London
# 30    Outer London
# 31    Inner London
# 32    Inner London
# Name: Inner_Outer_London, dtype: object

# %% [markdown]
# But looking at the column info, we can also see that the column number/index (#) is 2. We can use this to call the column, using the `dataframe.iloc[row_number, column_number]` function. If we want to specify the whole column or row, we use the : symbol. For example, to see all rows of column 2:

# %%
boroughs.iloc[:,[2]]
# Out:
#    Inner_Outer_London
# 0        Inner London
# 1        Outer London
# 2        Outer London
# 3        Outer London
# 4        Outer London
# 5        Outer London
# 6        Inner London
# 7        Outer London
# 8        Outer London
# 9        Outer London
# 10       Outer London
# 11       Inner London
# 12       Inner London
# 13       Inner London
# 14       Outer London
# 15       Outer London
# 16       Outer London
# 17       Outer London
# 18       Inner London
# 19       Inner London
# 20       Outer London
# 21       Inner London
# 22       Inner London
# 23       Outer London
# 24       Inner London
# 25       Outer London
# 26       Outer London
# 27       Inner London
# 28       Outer London
# 29       Inner London
# 30       Outer London
# 31       Inner London
# 32       Inner London

# %% [markdown]
# Or to just view row 25, column 2:

# %%
boroughs.iloc[[25], [2]]
# Out:
#    Inner_Outer_London
# 25       Outer London

# %% [markdown]
# Or for all of row 7:

# %%
boroughs.iloc[[7],:]
# Out:
#         Code Area_name Inner_Outer_London  Population  Area  Average_Age  \
# 7  E09000008   Croydon       Outer London      386500  86.5         37.0
#
#   Largest_migrant_population  Employment_rate Median_income  Jobs_Density  \
# 7                      India             75.4        37,000           0.6
#
#    ... Rented_private  Greenspace  Carbon_emissions  Household_recycling  \
# 7  ...           18.6        37.1              1237                 39.9
#
#    Cars_per_HH  Public_transport  Male_life_expectancy  \
# 7          1.0               3.2                  80.3
#
#    Female_life_expectancy  Life_satisfaction  Council
# 7                    83.6                7.1      Lab
#
# [1 rows x 27 columns]

# %% [markdown]
# This system can be a little bit confusing, so have a play around on the next couple of rows to get the hang of it.

# %%
#call all of column 25
boroughs.iloc[:, [25]]
# Out:
#     Life_satisfaction
# 0                 6.6
# 1                 7.1
# 2                 7.5
# 3                 7.4
# 4                 7.3
# 5                 7.5
# 6                 7.1
# 7                 7.1
# 8                 7.3
# 9                 7.3
# 10                7.2
# 11                7.0
# 12                7.4
# 13                7.2
# 14                7.3
# 15                7.4
# 16                7.4
# 17                7.3
# 18                7.2
# 19                7.6
# 20                7.3
# 21                7.1
# 22                7.2
# 23                7.3
# 24                7.1
# 25                7.3
# 26                7.5
# 27                7.5
# 28                7.5
# 29                7.2
# 30                7.2
# 31                7.4
# 32                7.3

# %%
#call all of row 12
boroughs.iloc[[12],:]
# Out:
#          Code               Area_name Inner_Outer_London  Population  Area  \
# 12  E09000013  Hammersmith and Fulham       Inner London      185300  16.4
#
#     Average_Age Largest_migrant_population  Employment_rate Median_income  \
# 12         35.7                     France             77.5        43,820
#
#     Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 12           1.2  ...           33.1        19.1               809
#
#     Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 12                 20.7          0.5               4.7                  79.7
#
#     Female_life_expectancy  Life_satisfaction  Council
# 12                    84.1                7.4      Lab
#
# [1 rows x 27 columns]

# %%
#call column 17, row 13
boroughs.iloc[[13],[17]]
# Out:
#     Rented_private
# 13            23.9

# %% [markdown]
# Can you figure out how to call multiple rows, by adding a list to where you add the rows? (ie`[['','']]`). Try calling up rows 12, 13, and 14 with one command

# %%
#call multiple rows
boroughs.iloc[[12,13,14], :]
# Out:
#          Code               Area_name Inner_Outer_London  Population   Area  \
# 12  E09000013  Hammersmith and Fulham       Inner London      185300  16.40
# 13  E09000014                Haringey       Inner London      278000  29.60
# 14  E09000015                  Harrow       Outer London      252300  50.46
#
#     Average_Age Largest_migrant_population  Employment_rate Median_income  \
# 12         35.7                     France             77.5        43,820
# 13         35.1                     Poland             71.3        35,420
# 14         38.3                      India             73.9        38,880
#
#     Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 12           1.2  ...           33.1        19.1               809
# 13           0.5  ...           23.9        25.5               773
# 14           0.6  ...           24.6        34.6               748
#
#     Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 12                 20.7          0.5               4.7                  79.7
# 13                 37.3          0.6               4.3                  80.1
# 14                 45.1          1.2               2.9                  82.7
#
#     Female_life_expectancy  Life_satisfaction  Council
# 12                    84.1                7.4      Lab
# 13                    84.9                7.2      Lab
# 14                    86.1                7.3      Lab
#
# [3 rows x 27 columns]

# %% [markdown]
# We can also call rows by name, as we practiced doing in the extension activities last week.

# %% [markdown]
# To call the borough named 'Westminster', we use a double equals sign `==` to tell Python to look for rows equal to that value, for example:

# %%
boroughs[(boroughs.Area_name == 'Westminster')]
# Out:
#          Code    Area_name Inner_Outer_London  Population   Area  Average_Age  \
# 32  E09000033  Westminster       Inner London      242100  21.49         37.7
#
#    Largest_migrant_population  Employment_rate Median_income  Jobs_Density  \
# 32              United States             65.6        47,510           4.3
#
#     ... Rented_private  Greenspace  Carbon_emissions  Household_recycling  \
# 32  ...           43.3        38.2              2502                 19.1
#
#     Cars_per_HH  Public_transport  Male_life_expectancy  \
# 32          0.5               6.5                  82.3
#
#     Female_life_expectancy  Life_satisfaction  Council
# 32                    86.3                7.3     Cons
#
# [1 rows x 27 columns]

# %% [markdown]
# Now try calling the borough called 'Camden':

# %%
#call up Camden
boroughs[(boroughs.Area_name == 'Camden')]
# Out:
#         Code Area_name Inner_Outer_London  Population   Area  Average_Age  \
# 6  E09000007    Camden       Inner London      242500  21.79         36.4
#
#   Largest_migrant_population  Employment_rate Median_income  Jobs_Density  \
# 6              United States             69.2        43,750           2.2
#
#    ... Rented_private  Greenspace  Carbon_emissions  Household_recycling  \
# 6  ...           32.0        24.8              1288                 26.3
#
#    Cars_per_HH  Public_transport  Male_life_expectancy  \
# 6          0.5               5.7                  81.8
#
#    Female_life_expectancy  Life_satisfaction  Council
# 6                    86.7                7.1      Lab
#
# [1 rows x 27 columns]

# %% [markdown]
# We can also use inequalities (ie: `>=`, `<=`, `<`,`>`) to find boroughs with values above or below a certain value. For example, we can find the borough where the average age is greater than or equal to 40

# %%
boroughs[(boroughs.Average_Age >= 40)]
# Out:
#          Code       Area_name Inner_Outer_London  Population    Area  \
# 0   E09000001  City of London       Inner London        8800    2.90
# 5   E09000006         Bromley       Outer London      327900  150.13
# 15  E09000016        Havering       Outer London      254300  112.35
#
#     Average_Age Largest_migrant_population  Employment_rate Median_income  \
# 0          43.2              United States             64.6        63,620
# 5          40.2                      India             75.3        43,060
# 15         40.3                    Ireland             76.5        36,670
#
#     Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 0           84.3  ...            NaN         4.8              1036
# 5            0.6  ...           14.1        57.8              1180
# 15           0.6  ...           13.8        59.3              1032
#
#     Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 0                  34.4          0.4               7.9                   NaN
# 5                  48.0          1.2               2.8                  81.4
# 15                 32.4          1.2               2.5                  80.2
#
#     Female_life_expectancy  Life_satisfaction             Council
# 0                      NaN                6.6                 NaN
# 5                     84.9                7.5                Cons
# 15                    83.9                7.4  No Overall Control
#
# [3 rows x 27 columns]

# %% [markdown]
# ## Setting Data Types

# %% [markdown]
# Earlier we called `.describe()` on the whole dataset. Let's now try describing the median income column:

# %%
#descibe the column
boroughs['Median_income'].describe()
# Out:
# count         33
# unique        33
# top       63,620
# freq           1
# Name: Median_income, dtype: object

# %% [markdown]
# This doesn't look quite right- we'd expect a numerical column to return the descriptive statistics (mean, median, max, etc). So what's gone wrong? Check the data type of the median income column using the `dtype` funtion.

# %%
boroughs['Median_income'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Income should be numeric, so we'd expect the function to return 'float64' or 'int64'. If you look at the numbers, compared to the other columns which have been correctly identified as numeric, can you see why? <br>

# %%
#view columns
boroughs.head()
# Out:
#         Code             Area_name Inner_Outer_London  Population   Area  \
# 0  E09000001        City of London       Inner London        8800   2.90
# 1  E09000002  Barking and Dagenham       Outer London      209000  36.11
# 2  E09000003                Barnet       Outer London      389600  86.75
# 3  E09000004                Bexley       Outer London      244300  60.58
# 4  E09000005                 Brent       Outer London      332100  43.23
#
#    Average_Age Largest_migrant_population  Employment_rate Median_income  \
# 0         43.2              United States             64.6        63,620
# 1         32.9                    Nigeria             65.8        29,420
# 2         37.3                      India             68.5        40,530
# 3         39.0                    Nigeria             75.1        36,990
# 4         35.6                      India             69.5        32,140
#
#    Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 0          84.3  ...            NaN         4.8              1036
# 1           0.5  ...           20.3        33.6               644
# 2           0.7  ...           31.1        41.3              1415
# 3           0.6  ...           11.4        31.7               975
# 4           0.6  ...           34.8        21.9              1175
#
#    Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 0                 34.4          0.4               7.9                   NaN
# 1                 23.4          0.8               3.0                  77.6
# 2                 38.0          1.1               3.0                  82.1
# 3                 54.0          1.2               2.6                  80.4
# 4                 35.2          0.8               3.7                  80.1
#
#    Female_life_expectancy  Life_satisfaction  Council
# 0                     NaN                6.6      NaN
# 1                    82.1                7.1      Lab
# 2                    85.1                7.5     Cons
# 3                    84.4                7.4     Cons
# 4                    85.1                7.3      Lab
#
# [5 rows x 27 columns]

# %% [markdown]
# We can convert it to a float using the `.astype()` function, and removing the commas (which Python is reading as text) using `.str.replace()`. Try it out below.

# %%
boroughs['Median_income'] = boroughs['Median_income'].str.replace(',','').astype(float) #replace commas with nothing (i.e. remove commas), then convert to float

# %%
boroughs['Median_income'].dtype
# Out:
# dtype('float64')

# %%
#describe the updated column
boroughs['Median_income'].describe()
# Out:
# count       33.000000
# mean     39642.121212
# std       7394.742118
# min      28780.000000
# 25%      35350.000000
# 50%      37040.000000
# 75%      43060.000000
# max      63620.000000
# Name: Median_income, dtype: float64

# %% [markdown]
# Woohoo- looks like it should have worked. Have a look if there are any other columns which should be numeric but have been read in as strings. Repeat the steps above, remember to use `.astype(int)` if you need an integer, or `.astype(float)` if you need decimal places

# %%
#check other columns
boroughs.head()
# Out:
#         Code             Area_name Inner_Outer_London  Population   Area  \
# 0  E09000001        City of London       Inner London        8800   2.90
# 1  E09000002  Barking and Dagenham       Outer London      209000  36.11
# 2  E09000003                Barnet       Outer London      389600  86.75
# 3  E09000004                Bexley       Outer London      244300  60.58
# 4  E09000005                 Brent       Outer London      332100  43.23
#
#    Average_Age Largest_migrant_population  Employment_rate  Median_income  \
# 0         43.2              United States             64.6        63620.0
# 1         32.9                    Nigeria             65.8        29420.0
# 2         37.3                      India             68.5        40530.0
# 3         39.0                    Nigeria             75.1        36990.0
# 4         35.6                      India             69.5        32140.0
#
#    Jobs_Density  ... Rented_private  Greenspace  Carbon_emissions  \
# 0          84.3  ...            NaN         4.8              1036
# 1           0.5  ...           20.3        33.6               644
# 2           0.7  ...           31.1        41.3              1415
# 3           0.6  ...           11.4        31.7               975
# 4           0.6  ...           34.8        21.9              1175
#
#    Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 0                 34.4          0.4               7.9                   NaN
# 1                 23.4          0.8               3.0                  77.6
# 2                 38.0          1.1               3.0                  82.1
# 3                 54.0          1.2               2.6                  80.4
# 4                 35.2          0.8               3.7                  80.1
#
#    Female_life_expectancy  Life_satisfaction  Council
# 0                     NaN                6.6      NaN
# 1                    82.1                7.1      Lab
# 2                    85.1                7.5     Cons
# 3                    84.4                7.4     Cons
# 4                    85.1                7.3      Lab
#
# [5 rows x 27 columns]

# %%
#update any other columns as needed
boroughs['Number_businesses'] = boroughs['Number_businesses'].str.replace(',','').astype(float) #replace commas with nothing (i.e. remove commas), then convert to float

# %%
#show it worked
boroughs['Number_businesses'].dtype
boroughs['Number_businesses']
# Out:
# 0     26130.0
# 1      6560.0
# 2     26190.0
# 3      9075.0
# 4     15745.0
# 5     15695.0
# 6     31385.0
# 7     15540.0
# 8     18700.0
# 9     13925.0
# 10    10060.0
# 11    18510.0
# 12    14095.0
# 13    12675.0
# 14    15155.0
# 15    10115.0
# 16    13505.0
# 17    13910.0
# 18    22110.0
# 19    14350.0
# 20     8970.0
# 21    17280.0
# 22    10405.0
# 23    12070.0
# 24    11055.0
# 25    14595.0
# 26    14185.0
# 27    17120.0
# 28     8710.0
# 29    18390.0
# 30    11020.0
# 31    18695.0
# 32    55385.0
# Name: Number_businesses, dtype: float64

# %% [markdown]
# <br><br><br>
#
# ## Pivot Tables
# Another way to reconfigure a subset of the data is using pivot tables, which (as the name might suggest), rearrange or _pivot_ variables, in order to examine different groupings. The `index` defines the rows, the `columns` will be our columns in the pivot table, and the `values` will be those in the table. To begin with, we can again look at the populaiton of each inner and outer London Borough, using Borough names:

# %%
boros_pivot = boroughs.pivot(index = 'Area_name', columns ='Inner_Outer_London', values = 'Population')

# %%
boros_pivot
# Out:
# Inner_Outer_London      Inner London  Outer London
# Area_name
# Barking and Dagenham             NaN      209000.0
# Barnet                           NaN      389600.0
# Bexley                           NaN      244300.0
# Brent                            NaN      332100.0
# Bromley                          NaN      327900.0
# Camden                      242500.0           NaN
# City of London                8800.0           NaN
# Croydon                          NaN      386500.0
# Ealing                           NaN      351600.0
# Enfield                          NaN      333000.0
# Greenwich                        NaN      280100.0
# Hackney                     274300.0           NaN
# Hammersmith and Fulham      185300.0           NaN
# Haringey                    278000.0           NaN
# Harrow                           NaN      252300.0
# Havering                         NaN      254300.0
# Hillingdon                       NaN      301000.0
# Hounslow                         NaN      274200.0
# Islington                   231200.0           NaN
# Kensington and Chelsea      159000.0           NaN
# Kingston upon Thames             NaN      175400.0
# Lambeth                     328900.0           NaN
# Lewisham                    303400.0           NaN
# Merton                           NaN      208100.0
# Newham                      342900.0           NaN
# Redbridge                        NaN      304200.0
# Richmond upon Thames             NaN      197300.0
# Southwark                   314300.0           NaN
# Sutton                           NaN      202600.0
# Tower Hamlets               304000.0           NaN
# Waltham Forest                   NaN      276200.0
# Wandsworth                  321000.0           NaN
# Westminster                 242100.0           NaN

# %% [markdown]
# We could also examine whether the employment rate varies according to the leading Political party:

# %%
boros_pivot2 = boroughs.pivot(index = 'Area_name', columns ='Council', values = 'Employment_rate')

# %%
#view the new pivot table
boros_pivot2
# Out:
# Council                  NaN  Cons   Lab  Lib Dem  No Overall Control  \
# Area_name
# Barking and Dagenham     NaN   NaN  65.8      NaN                 NaN
# Barnet                   NaN  68.5   NaN      NaN                 NaN
# Bexley                   NaN  75.1   NaN      NaN                 NaN
# Brent                    NaN   NaN  69.5      NaN                 NaN
# Bromley                  NaN  75.3   NaN      NaN                 NaN
# Camden                   NaN   NaN  69.2      NaN                 NaN
# City of London          64.6   NaN   NaN      NaN                 NaN
# Croydon                  NaN   NaN  75.4      NaN                 NaN
# Ealing                   NaN   NaN  72.7      NaN                 NaN
# Enfield                  NaN   NaN  73.0      NaN                 NaN
# Greenwich                NaN   NaN  72.1      NaN                 NaN
# Hackney                  NaN   NaN  69.0      NaN                 NaN
# Hammersmith and Fulham   NaN   NaN  77.5      NaN                 NaN
# Haringey                 NaN   NaN  71.3      NaN                 NaN
# Harrow                   NaN   NaN  73.9      NaN                 NaN
# Havering                 NaN   NaN   NaN      NaN                76.5
# Hillingdon               NaN  73.2   NaN      NaN                 NaN
# Hounslow                 NaN   NaN  74.2      NaN                 NaN
# Islington                NaN   NaN  72.6      NaN                 NaN
# Kensington and Chelsea   NaN  68.2   NaN      NaN                 NaN
# Kingston upon Thames     NaN  74.4   NaN      NaN                 NaN
# Lambeth                  NaN   NaN  78.5      NaN                 NaN
# Lewisham                 NaN   NaN  75.9      NaN                 NaN
# Merton                   NaN   NaN  78.8      NaN                 NaN
# Newham                   NaN   NaN  66.2      NaN                 NaN
# Redbridge                NaN   NaN  68.3      NaN                 NaN
# Richmond upon Thames     NaN  79.6   NaN      NaN                 NaN
# Southwark                NaN   NaN  74.2      NaN                 NaN
# Sutton                   NaN   NaN   NaN     78.2                 NaN
# Tower Hamlets            NaN   NaN   NaN      NaN                 NaN
# Waltham Forest           NaN   NaN  73.1      NaN                 NaN
# Wandsworth               NaN  78.8   NaN      NaN                 NaN
# Westminster              NaN  65.6   NaN      NaN                 NaN
#
# Council                 Tower Hamlets First
# Area_name
# Barking and Dagenham                    NaN
# Barnet                                  NaN
# Bexley                                  NaN
# Brent                                   NaN
# Bromley                                 NaN
# Camden                                  NaN
# City of London                          NaN
# Croydon                                 NaN
# Ealing                                  NaN
# Enfield                                 NaN
# Greenwich                               NaN
# Hackney                                 NaN
# Hammersmith and Fulham                  NaN
# Haringey                                NaN
# Harrow                                  NaN
# Havering                                NaN
# Hillingdon                              NaN
# Hounslow                                NaN
# Islington                               NaN
# Kensington and Chelsea                  NaN
# Kingston upon Thames                    NaN
# Lambeth                                 NaN
# Lewisham                                NaN
# Merton                                  NaN
# Newham                                  NaN
# Redbridge                               NaN
# Richmond upon Thames                    NaN
# Southwark                               NaN
# Sutton                                  NaN
# Tower Hamlets                          70.4
# Waltham Forest                          NaN
# Wandsworth                              NaN
# Westminster                             NaN

# %% [markdown]
# <br><br>
# Now it's your turn to make some more pivot tables, following the questions below. Try making some of your own, according to variables you're interested in. Just make sure your index contains unique values, or it won't work!

# %%
#how does the percentage of greenspace vary in inner and outer London?
boros_pivot3 = boroughs.pivot(index = 'Area_name', columns = 'Inner_Outer_London', values = 'Greenspace')
boros_pivot3
# Out:
# Inner_Outer_London      Inner London  Outer London
# Area_name
# Barking and Dagenham             NaN          33.6
# Barnet                           NaN          41.3
# Bexley                           NaN          31.7
# Brent                            NaN          21.9
# Bromley                          NaN          57.8
# Camden                          24.8           NaN
# City of London                   4.8           NaN
# Croydon                          NaN          37.1
# Ealing                           NaN          30.9
# Enfield                          NaN          45.6
# Greenwich                        NaN          34.4
# Hackney                         23.2           NaN
# Hammersmith and Fulham          19.1           NaN
# Haringey                        25.5           NaN
# Harrow                           NaN          34.6
# Havering                         NaN          59.3
# Hillingdon                       NaN          49.2
# Hounslow                         NaN          39.6
# Islington                       12.4           NaN
# Kensington and Chelsea          15.1           NaN
# Kingston upon Thames             NaN          36.4
# Lambeth                         17.3           NaN
# Lewisham                        22.5           NaN
# Merton                           NaN          34.6
# Newham                          23.9           NaN
# Redbridge                        NaN          40.6
# Richmond upon Thames             NaN          50.8
# Southwark                       24.9           NaN
# Sutton                           NaN          32.0
# Tower Hamlets                   15.2           NaN
# Waltham Forest                   NaN          31.4
# Wandsworth                      26.9           NaN
# Westminster                     38.2           NaN

# %%
#how does life satifaction differ according to the leading polictical party?
boros_pivot4 = boroughs.pivot(index = 'Area_name', columns = 'Council', values = 'Life_satisfaction')
boros_pivot4
# Out:
# Council                 NaN  Cons  Lab  Lib Dem  No Overall Control  \
# Area_name
# Barking and Dagenham    NaN   NaN  7.1      NaN                 NaN
# Barnet                  NaN   7.5  NaN      NaN                 NaN
# Bexley                  NaN   7.4  NaN      NaN                 NaN
# Brent                   NaN   NaN  7.3      NaN                 NaN
# Bromley                 NaN   7.5  NaN      NaN                 NaN
# Camden                  NaN   NaN  7.1      NaN                 NaN
# City of London          6.6   NaN  NaN      NaN                 NaN
# Croydon                 NaN   NaN  7.1      NaN                 NaN
# Ealing                  NaN   NaN  7.3      NaN                 NaN
# Enfield                 NaN   NaN  7.3      NaN                 NaN
# Greenwich               NaN   NaN  7.2      NaN                 NaN
# Hackney                 NaN   NaN  7.0      NaN                 NaN
# Hammersmith and Fulham  NaN   NaN  7.4      NaN                 NaN
# Haringey                NaN   NaN  7.2      NaN                 NaN
# Harrow                  NaN   NaN  7.3      NaN                 NaN
# Havering                NaN   NaN  NaN      NaN                 7.4
# Hillingdon              NaN   7.4  NaN      NaN                 NaN
# Hounslow                NaN   NaN  7.3      NaN                 NaN
# Islington               NaN   NaN  7.2      NaN                 NaN
# Kensington and Chelsea  NaN   7.6  NaN      NaN                 NaN
# Kingston upon Thames    NaN   7.3  NaN      NaN                 NaN
# Lambeth                 NaN   NaN  7.1      NaN                 NaN
# Lewisham                NaN   NaN  7.2      NaN                 NaN
# Merton                  NaN   NaN  7.3      NaN                 NaN
# Newham                  NaN   NaN  7.1      NaN                 NaN
# Redbridge               NaN   NaN  7.3      NaN                 NaN
# Richmond upon Thames    NaN   7.5  NaN      NaN                 NaN
# Southwark               NaN   NaN  7.5      NaN                 NaN
# Sutton                  NaN   NaN  NaN      7.5                 NaN
# Tower Hamlets           NaN   NaN  NaN      NaN                 NaN
# Waltham Forest          NaN   NaN  7.2      NaN                 NaN
# Wandsworth              NaN   7.4  NaN      NaN                 NaN
# Westminster             NaN   7.3  NaN      NaN                 NaN
#
# Council                 Tower Hamlets First
# Area_name
# Barking and Dagenham                    NaN
# Barnet                                  NaN
# Bexley                                  NaN
# Brent                                   NaN
# Bromley                                 NaN
# Camden                                  NaN
# City of London                          NaN
# Croydon                                 NaN
# Ealing                                  NaN
# Enfield                                 NaN
# Greenwich                               NaN
# Hackney                                 NaN
# Hammersmith and Fulham                  NaN
# Haringey                                NaN
# Harrow                                  NaN
# Havering                                NaN
# Hillingdon                              NaN
# Hounslow                                NaN
# Islington                               NaN
# Kensington and Chelsea                  NaN
# Kingston upon Thames                    NaN
# Lambeth                                 NaN
# Lewisham                                NaN
# Merton                                  NaN
# Newham                                  NaN
# Redbridge                               NaN
# Richmond upon Thames                    NaN
# Southwark                               NaN
# Sutton                                  NaN
# Tower Hamlets                           7.2
# Waltham Forest                          NaN
# Wandsworth                              NaN
# Westminster                             NaN

# %%
#does employment look different for areas with different migrant populations?
boros_pivot5 = boroughs.pivot(index = 'Area_name', columns = 'Largest_migrant_population', values = 'Employment_rate')
boros_pivot5
# Out:
# Largest_migrant_population  Bangladesh  France  India  Ireland  Jamaica  \
# Area_name
# Barking and Dagenham               NaN     NaN    NaN      NaN      NaN
# Barnet                             NaN     NaN   68.5      NaN      NaN
# Bexley                             NaN     NaN    NaN      NaN      NaN
# Brent                              NaN     NaN   69.5      NaN      NaN
# Bromley                            NaN     NaN   75.3      NaN      NaN
# Camden                             NaN     NaN    NaN      NaN      NaN
# City of London                     NaN     NaN    NaN      NaN      NaN
# Croydon                            NaN     NaN   75.4      NaN      NaN
# Ealing                             NaN     NaN   72.7      NaN      NaN
# Enfield                            NaN     NaN    NaN      NaN      NaN
# Greenwich                          NaN     NaN    NaN      NaN      NaN
# Hackney                            NaN     NaN    NaN      NaN      NaN
# Hammersmith and Fulham             NaN    77.5    NaN      NaN      NaN
# Haringey                           NaN     NaN    NaN      NaN      NaN
# Harrow                             NaN     NaN   73.9      NaN      NaN
# Havering                           NaN     NaN    NaN     76.5      NaN
# Hillingdon                         NaN     NaN   73.2      NaN      NaN
# Hounslow                           NaN     NaN   74.2      NaN      NaN
# Islington                          NaN     NaN    NaN     72.6      NaN
# Kensington and Chelsea             NaN     NaN    NaN      NaN      NaN
# Kingston upon Thames               NaN     NaN    NaN      NaN      NaN
# Lambeth                            NaN     NaN    NaN      NaN     78.5
# Lewisham                           NaN     NaN    NaN      NaN     75.9
# Merton                             NaN     NaN    NaN      NaN      NaN
# Newham                             NaN     NaN   66.2      NaN      NaN
# Redbridge                          NaN     NaN   68.3      NaN      NaN
# Richmond upon Thames               NaN     NaN    NaN     79.6      NaN
# Southwark                          NaN     NaN    NaN      NaN      NaN
# Sutton                             NaN     NaN    NaN      NaN      NaN
# Tower Hamlets                     70.4     NaN    NaN      NaN      NaN
# Waltham Forest                     NaN     NaN    NaN      NaN      NaN
# Wandsworth                         NaN     NaN    NaN      NaN      NaN
# Westminster                        NaN     NaN    NaN      NaN      NaN
#
# Largest_migrant_population  Nigeria  Pakistan  Poland  Sri Lanka  Turkey  \
# Area_name
# Barking and Dagenham           65.8       NaN     NaN        NaN     NaN
# Barnet                          NaN       NaN     NaN        NaN     NaN
# Bexley                         75.1       NaN     NaN        NaN     NaN
# Brent                           NaN       NaN     NaN        NaN     NaN
# Bromley                         NaN       NaN     NaN        NaN     NaN
# Camden                          NaN       NaN     NaN        NaN     NaN
# City of London                  NaN       NaN     NaN        NaN     NaN
# Croydon                         NaN       NaN     NaN        NaN     NaN
# Ealing                          NaN       NaN     NaN        NaN     NaN
# Enfield                         NaN       NaN     NaN        NaN    73.0
# Greenwich                      72.1       NaN     NaN        NaN     NaN
# Hackney                         NaN       NaN     NaN        NaN    69.0
# Hammersmith and Fulham          NaN       NaN     NaN        NaN     NaN
# Haringey                        NaN       NaN    71.3        NaN     NaN
# Harrow                          NaN       NaN     NaN        NaN     NaN
# Havering                        NaN       NaN     NaN        NaN     NaN
# Hillingdon                      NaN       NaN     NaN        NaN     NaN
# Hounslow                        NaN       NaN     NaN        NaN     NaN
# Islington                       NaN       NaN     NaN        NaN     NaN
# Kensington and Chelsea          NaN       NaN     NaN        NaN     NaN
# Kingston upon Thames            NaN       NaN     NaN       74.4     NaN
# Lambeth                         NaN       NaN     NaN        NaN     NaN
# Lewisham                        NaN       NaN     NaN        NaN     NaN
# Merton                          NaN       NaN    78.8        NaN     NaN
# Newham                          NaN       NaN     NaN        NaN     NaN
# Redbridge                       NaN       NaN     NaN        NaN     NaN
# Richmond upon Thames            NaN       NaN     NaN        NaN     NaN
# Southwark                      74.2       NaN     NaN        NaN     NaN
# Sutton                          NaN       NaN     NaN       78.2     NaN
# Tower Hamlets                   NaN       NaN     NaN        NaN     NaN
# Waltham Forest                  NaN      73.1     NaN        NaN     NaN
# Wandsworth                      NaN       NaN    78.8        NaN     NaN
# Westminster                     NaN       NaN     NaN        NaN     NaN
#
# Largest_migrant_population  United States
# Area_name
# Barking and Dagenham                  NaN
# Barnet                                NaN
# Bexley                                NaN
# Brent                                 NaN
# Bromley                               NaN
# Camden                               69.2
# City of London                       64.6
# Croydon                               NaN
# Ealing                                NaN
# Enfield                               NaN
# Greenwich                             NaN
# Hackney                               NaN
# Hammersmith and Fulham                NaN
# Haringey                              NaN
# Harrow                                NaN
# Havering                              NaN
# Hillingdon                            NaN
# Hounslow                              NaN
# Islington                             NaN
# Kensington and Chelsea               68.2
# Kingston upon Thames                  NaN
# Lambeth                               NaN
# Lewisham                              NaN
# Merton                                NaN
# Newham                                NaN
# Redbridge                             NaN
# Richmond upon Thames                  NaN
# Southwark                             NaN
# Sutton                                NaN
# Tower Hamlets                         NaN
# Waltham Forest                        NaN
# Wandsworth                            NaN
# Westminster                          65.6

# %%
#now try out some of your own!

# %% [markdown]
# <br><br><br>
# ## Finishing Up

# %% [markdown]
# While Colab saves our session temporarily online, we need to make sure we download our file in order to come back to our updates later. This is easy to do- just go to File > Download > .ipynb to keep your Python notebooks permanently.
# <br>
# If you're a Github user, or want to start building your own portfolio of your Python skills, you can use File > Save a copy in Github, select your repository and filepath, and off you go! (If you're not sure what any of this Github talk means- don't worry! We'll be coming back to this!)

# %% [markdown]
# <br><br><br>
# ## Further Questions

# %% [markdown]
# <br>
# <br>
#
# __Question 1:__ Pick a variable that seems most interesting to you, assign it to a variable, and have a look at different descriptors we've used to get more information about your variable(s) of choice. Try adding some comments and Markdown cells to record what you've done.

# %% [markdown]
# I am most interested in sustainability variables, such as Public_transport, cars_per_hh, Houshold_recycling, Carbon_emissions, Greenspace

# %%
PublicTran = boroughs['Public_transport'] #Creates a new variable with public transport information
PublicTran.info() #Gives key information about the variable
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 33 entries, 0 to 32
# Series name: Public_transport
# Non-Null Count  Dtype
# --------------  -----
# 33 non-null     float64
# dtypes: float64(1)
# memory usage: 392.0 bytes

# %%
PublicTran.head() #Displays the first five rows of the data
# Out:
# 0    7.9
# 1    3.0
# 2    3.0
# 3    2.6
# 4    3.7
# Name: Public_transport, dtype: float64

# %%
PublicTran.describe() #Generates summary statistics
# Out:
# count    33.000000
# mean      3.951515
# std       1.304588
# min       2.400000
# 25%       3.000000
# 50%       3.400000
# 75%       4.900000
# max       7.900000
# Name: Public_transport, dtype: float64

# %% [markdown]
# __Question 2:__ Create histograms of each of the numerical variables. Compare the distributions. Which looks the most similar? Why do you think this might be?

# %%
Cars = boroughs['Cars_per_HH'] #Creates a new variable with cars per household information
Recycling = boroughs['Household_recycling'] #Creates a new variable with recycling information
Carbon = boroughs['Carbon_emissions'] #Creates a new variable with carbon emissions information
Green = boroughs['Greenspace'] #Creates a new variable with greenspace information

# %%
PublicTran.hist()
# Out:
# <Axes: >

# %%
Cars.hist()
# Out:
# <Axes: >

# %%
Recycling.hist()
# Out:
# <Axes: >

# %%
Carbon.hist()
# Out:
# <Axes: >

# %%
Green.hist()
# Out:
# <Axes: >

# %% [markdown]
# We notice that the distributions for public transport and carbon emissions are very similar, suggesting that these two variables are linked, as we might expect. That is, areas with more public transport tend to have lower carbon emissions (less people driving) whilst areas with less public transport tend to have more carbon emissions (more people driving).

# %% [markdown]
# __Question 3:__ If you're up for a challenge, have a look through [this tutorial](https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html) to create a subset of the data for Inner London. Then use what we've learnt above to answer the following:
# _a:_ What is the average house price?
# _b:_ Which Borough has the highest emissions?
# _c:_ How many of each Council Party are there?
# _d:_ Can you make a histogram of life Satisfaction?

# %%
Inner_London_boroughs = boroughs[boroughs['Inner_Outer_London'] == 'Inner London'] #Creates a subset of all inner london boroughs

# %%
Inner_London_boroughs #display the data to check that it is correct
# Out:
#          Code               Area_name Inner_Outer_London  Population   Area  \
# 0   E09000001          City of London       Inner London        8800   2.90
# 6   E09000007                  Camden       Inner London      242500  21.79
# 11  E09000012                 Hackney       Inner London      274300  19.05
# 12  E09000013  Hammersmith and Fulham       Inner London      185300  16.40
# 13  E09000014                Haringey       Inner London      278000  29.60
# 18  E09000019               Islington       Inner London      231200  14.86
# 19  E09000020  Kensington and Chelsea       Inner London      159000  12.12
# 21  E09000022                 Lambeth       Inner London      328900  26.81
# 22  E09000023                Lewisham       Inner London      303400  35.15
# 24  E09000025                  Newham       Inner London      342900  36.20
# 27  E09000028               Southwark       Inner London      314300  28.86
# 29  E09000030           Tower Hamlets       Inner London      304000  19.78
# 31  E09000032              Wandsworth       Inner London      321000  34.26
# 32  E09000033             Westminster       Inner London      242100  21.49
#
#     Average_Age Largest_migrant_population  Employment_rate  Median_income  \
# 0          43.2              United States             64.6        63620.0
# 6          36.4              United States             69.2        43750.0
# 11         33.1                     Turkey             69.0        35140.0
# 12         35.7                     France             77.5        43820.0
# 13         35.1                     Poland             71.3        35420.0
# 18         34.8                    Ireland             72.6        39790.0
# 19         39.3              United States             68.2        55620.0
# 21         34.5                    Jamaica             78.5        38490.0
# 22         35.0                    Jamaica             75.9        35900.0
# 24         32.1                      India             66.2        28780.0
# 27         34.4                    Nigeria             74.2        37100.0
# 29         31.4                 Bangladesh             70.4        34930.0
# 31         35.0                     Poland             78.8        47480.0
# 32         37.7              United States             65.6        47510.0
#
#     Jobs_Density  ...  Rented_private  Greenspace  Carbon_emissions  \
# 0           84.3  ...             NaN         4.8              1036
# 6            2.2  ...            32.0        24.8              1288
# 11           0.7  ...            23.3        23.2               813
# 12           1.2  ...            33.1        19.1               809
# 13           0.5  ...            23.9        25.5               773
# 18           1.5  ...            25.5        12.4               878
# 19           1.4  ...            33.1        15.1              1154
# 21           0.8  ...            34.4        17.3              1091
# 22           0.4  ...            23.6        22.5               825
# 24           0.5  ...            42.5        23.9              1261
# 27           1.3  ...            26.4        24.9              1169
# 29           1.4  ...            31.5        15.2              1703
# 31           0.6  ...            31.2        26.9              1038
# 32           4.3  ...            43.3        38.2              2502
#
#     Household_recycling  Cars_per_HH  Public_transport  Male_life_expectancy  \
# 0                  34.4          0.4               7.9                   NaN
# 6                  26.3          0.5               5.7                  81.8
# 11                 25.3          0.4               4.9                  78.5
# 12                 20.7          0.5               4.7                  79.7
# 13                 37.3          0.6               4.3                  80.1
# 18                 32.8          0.4               5.7                  79.0
# 19                 25.3          0.6               5.8                  83.3
# 21                 28.3          0.5               5.0                  78.9
# 22                 17.1          0.7               4.1                  79.0
# 24                 17.2          0.6               3.9                  78.5
# 27                 34.6          0.5               4.9                  78.9
# 29                 28.1          0.4               5.0                  78.1
# 31                 20.7          0.7               4.3                  79.5
# 32                 19.1          0.5               6.5                  82.3
#
#     Female_life_expectancy  Life_satisfaction              Council
# 0                      NaN                6.6                  NaN
# 6                     86.7                7.1                  Lab
# 11                    83.3                7.0                  Lab
# 12                    84.1                7.4                  Lab
# 13                    84.9                7.2                  Lab
# 18                    83.5                7.2                  Lab
# 19                    86.4                7.6                 Cons
# 21                    83.3                7.1                  Lab
# 22                    83.4                7.2                  Lab
# 24                    83.0                7.1                  Lab
# 27                    83.9                7.5                  Lab
# 29                    82.5                7.2  Tower Hamlets First
# 31                    83.7                7.4                 Cons
# 32                    86.3                7.3                 Cons
#
# [14 rows x 27 columns]

# %%
HousePrice = Inner_London_boroughs['Median_House_Price'] #Variable to store median house prices

# %%
HousePrice.mean() #calculates the mean "median house price" for all Inner London boroughs.
# Out:
# 600321.3571428572

# %%
Carbon = Inner_London_boroughs['Carbon_emissions'] #Variable to store carbon emissions

# %%
Carbon.max() #Calculates the maximum carbon emissions
# Out:
# 2502

# %%
Carbon #Displays the data
# Out:
# 0     1036
# 6     1288
# 11     813
# 12     809
# 13     773
# 18     878
# 19    1154
# 21    1091
# 22     825
# 24    1261
# 27    1169
# 29    1703
# 31    1038
# 32    2502
# Name: Carbon_emissions, dtype: int64

# %% [markdown]
# The maximum is at index 32, which corresponds to Westminster, so this is the inner london borough with the highest carbon emissions.

# %%
Council = Inner_London_boroughs['Council'] #Creates a new variable to store the councils

# %%
Council.value_counts() #Counts how many councils are labour, conservative etc.
# Out:
# Council
# Lab                    9
# Cons                   3
# Tower Hamlets First    1
# Name: count, dtype: int64

# %% [markdown]
# There are 9 labour councils and 3 conservative councils in Inner London.

# %%
LifeSat = Inner_London_boroughs['Life_satisfaction'] #Creates a variable to store life satisfaction

# %%
LifeSat.hist() #Creates a histogram for life satisfaction
# Out:
# <Axes: >
